# %% [markdown]
# # Kissipo-CNN-CIFAR10(1)
# The CIFAR-10 dataset was developed by Alex Krizhevsky while a student at the University of Toronto, and available for download online https://www.cs.toronto.edu/~kriz/cifar.html.
# ![Mnist](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSHYlnmKLUZlYCicBU5A-X58K12YKbKeIx8by9GK2bNyMs8YUB64A5jpxKF-axkwzuPirQ&usqp=CAU)

# %% [markdown]
# ##  載入TF2.0所需的函數庫

# %%
import tensorflow as tf
print(tf.__version__)

# %% [markdown]
# # Part-1 The training phase

# %% [markdown]
# ## IPO-M: Building a DL model (Sequential API, Graph mode)
# $M(x)=\hat{y}$

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', activation ='relu', input_shape = (32,32,3)),
  tf.keras.layers.MaxPool2D(pool_size=(2,2)),
  tf.keras.layers.Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', activation ='relu'),
  tf.keras.layers.MaxPool2D(pool_size=(2,2)),
  tf.keras.layers.Dropout(0.25),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# ## IPO-I: input data

# %% [markdown]
# ### 載入CIFAR-10 數據集。

# %%
cifar10 = tf.keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
type(x_train)

# %%
print(x_train.shape)
print(x_test.shape)

# %% [markdown]
# ## IPO-O: ontput data

# %%
print(y_train.shape)
print(y_test.shape)

# %%
# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)
print(y_train.shape)
print(y_test.shape)

# %% [markdown]
# ## IPO-P: Training model

# %% [markdown]
# ###  選擇一個優化器和損失函數進行模型建構
# The from_logits=True attribute inform the loss function that the output values generated by the model are not normalized, a.k.a. logits. In other words, the softmax function has not been applied on them to produce a probability distribution.

# %%
#loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
loss_fn = tf.keras.losses.CategoricalCrossentropy(from_logits=False)

# %%
#Create an optimizer with the desired parameters.
opt = tf.keras.optimizers.SGD(learning_rate=0.1)

# %% [markdown]
# ### Compile model

# %%
model.compile(optimizer=opt, loss=loss_fn, metrics=['accuracy'])

# %% [markdown]
# ##  進行模型訓練

# %%
model.fit(x_train, y_train, epochs=10)

# %% [markdown]
# ## IPO-P: Evaluating model (模型評估)

# %%
model.evaluate(x_test,  y_test)

# %%
import numpy as np
from PIL import Image
from IPython.display import display

# %% [markdown]
# # Part-2 The Inference phase

# %% [markdown]
# ## IPO-M: Predicting the digit of an image
# $M(x)=\hat{y}$

# %% [markdown]
# ## IPO-I2: input a single image

# %% [markdown]
# ### 第一次

# %%
#show image real size
img = Image.open('bird1.bmp')
display(img)
img2=img.resize((32, 32))
img.close()

# %%
#show image at the size of 28x28
display(img2)

# %% [markdown]
# ### Covert an image to a numpy.ndarray (1, 28, 28)

# %%
im2arr = np.array(img2)/ 255.0
im2arr = im2arr.reshape(1,32,32, 3)

# %% [markdown]
# ## IPO-P2: model.predict

# %%
y_pred = model.predict(im2arr)
print(y_pred)

# %%
y_hat =np.argmax(y_pred)
y_hat
